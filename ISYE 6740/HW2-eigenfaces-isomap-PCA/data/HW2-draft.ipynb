# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
Image.open('yalefaces'+ os.path.sep+'subject01.glasses.gif')
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x1B7046A5390>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mouso\\Spring2022\\ISYE6414\\homework2\\data'
